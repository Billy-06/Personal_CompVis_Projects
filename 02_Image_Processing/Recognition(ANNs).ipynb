# %%
import numpy as np
import pickle
import os
import skimage.io as skk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import skimage.io, skimage.color, skimage.feature


apple = skimage.io.imread(fname="apple.jpg", as_gray=True)
raspberry = skimage.io.imread(fname="raspberry.jpg", as_gray= True)
lemon = skimage.io.imread(fname='lemon.jpg', as_gray=True)
mango = skimage.io.imread(fname='mango.jpg',as_gray=True)
plt.imshow(apple)

# %%
apple.shape
# Out:
# (225, 225)

# %%
raspberry.shape
# Out:
# (183, 275)

# %%
plt.imshow(raspberry)

# %%
apple = skimage.io.imread(fname="apple.jpg", as_gray=False)
raspberry = skimage.io.imread(fname="raspberry.jpg", as_gray=False)
lemon = skimage.io.imread(fname='lemon.jpg', as_gray=False)
mango = skimage.io.imread(fname='mango.jpg',as_gray=False)

# %%
apple.shape
# Out:
# (225, 225, 3)

# %%
raspberry.shape
# Out:
# (183, 275, 3)

# %%
lemon.shape
# Out:
# (500, 500, 3)

# %%
mango.shape
# Out:
# (183, 276, 3)

# %%
plt.imshow(lemon)

# %%
plt.imshow(raspberry)

# %%
plt.imshow(apple)

# %%
plt.imshow(mango)

# %%
fruits_data = [apple, raspberry, mango, lemon]
fruits = ['apple', 'raspberry', 'mango', 'lemon']

# %%
hist = np.histogram(a=apple[:,:,ch_num], bins=256)
plt.bar(x=np.arange(256), height=hist[0])
# Out:
# <BarContainer object of 256 artists>

# %%
hist = np.histogram(a=mango[:,:,ch_num], bins=256)
plt.bar(x=np.arange(256), height=hist[0])
# Out:
# <BarContainer object of 256 artists>

# %%
hist = np.histogram(a=lemon[:,:,ch_num], bins=256)
plt.bar(x=np.arange(256), height=hist[0])
# Out:
# <BarContainer object of 256 artists>

# %%
hist = np.histogram(a=raspberry[:,:,ch_num], bins=256)
plt.bar(x=np.arange(256), height=hist[0])
# Out:
# <BarContainer object of 256 artists>

# %%
apple_hsv = skimage.color.rgb2hsv(rgb=apple)
mango_hsv = skimage.color.rgb2hsv(rgb=mango)
raspberry_hsv = skimage.color.rgb2hsv(rgb=raspberry)
lemon_hsv = skimage.color.rgb2hsv(rgb=lemon)

hsv_fruits = [apple_hsv, mango_hsv, raspberry_hsv, lemon_hsv]

# %%
hist = np.histogram(a=lemon_hsv[:,:,0], bins=360)
plt.bar(x=np.arange(360), height=hist[0])
# Out:
# <BarContainer object of 360 artists>

# %%
lemon_hsv.shape
# Out:
# (500, 500, 3)

# %%
hist = np.histogram(a=lemon_hsv[:,:,1], bins=360)
plt.bar(x=np.arange(360), height=hist[0])
# Out:
# <BarContainer object of 360 artists>

# %%
hist = np.histogram(a=lemon_hsv[:,:,2], bins=360)
plt.bar(x=np.arange(360), height=hist[0])
# Out:
# <BarContainer object of 360 artists>

# %%
#Feature reduction

import numpy as np
import skimage.io, skimage.color, skimage.feature
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
apple = skimage.io.imread(fname="apple.jpg", as_gray=False)
raspberry = skimage.io.imread(fname="raspberry.jpg", as_gray=False)
lemon = skimage.io.imread(fname='lemon.jpg', as_gray=False)
mango = skimage.io.imread(fname='mango.jpg',as_gray=False)

fruits = ['apple.jpg', 'raspberry.jpg', 'mango.jpg', 'lemon.jpg']
dataset_features = np.zeros(shape=(1962, 360))
output = np.zeros(shape=1962)
