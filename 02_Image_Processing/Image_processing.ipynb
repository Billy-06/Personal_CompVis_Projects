# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('Computer-Vision-with-Python_udemy/DATA/00-puppy.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import cv2

# %%
img1 = cv2.imread('Computer-Vision-with-Python_udemy/DATA/dog_backpack.png')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('Computer-Vision-with-Python_udemy/DATA/watermark-no-copy.png')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)
